# %% [markdown]
# CARREGANDO OS DADOS

# %%
pip install control
# Out:
# ...
#   Obtaining dependency information for control from https://files.pythonhosted.org/packages/f2/0a/9f4c2a811b065c92f2483f26657dca373699388c959193ef27a644af1805/control-0.10.2-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/578.3 kB ? eta -:--:--
#    --------------- ------------------------ 225.3/578.3 kB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 578.3/578.3 kB 6.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import control as ctrl

# %% [markdown]
# Plot dos gráficos

# %%
# Definindo a função de tranferência G(s)
num = np.array([1, 4])
den = np.array([1, 3.2, 2.4, 0])

Valores_K = [2, 5, 9.6] # Valores de K que irão ser testados

G_s = ctrl.TransferFunction(num, den) # Criando a função de transferência G(s)

for K in Valores_K:
    G_s_K = G_s * K # Multiplicação em cascata 
    G_malha_fechada = ctrl.feedback(G_s_K, 1) # Gerando a malha fechada com realimentação unitária
    t, y = ctrl.step_response(G_malha_fechada) # Gerando a resposta ao degrau unitário 
    plt.plot(t, y, label=f'K = {K}')
    plt.title(f"Resposta ao Degrau para K = {K}")
    plt.xlabel("Tempo (s)")
    plt.ylabel("Amplitude")
    plt.grid()
    plt.show()
